# %% [markdown]
# # Time Headway Calculator
#
# The goal of this notebook is to establish time headways for individual following events, as a histogram based on the speed of the following vehicle.
#
# Authors: Sally Kim, Jonathan Sprinkle

# %%
import signal
import pandas as pd
import sys, math, time, datetime
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import style
import numpy as np
from matplotlib.pyplot import cm
import pickle
from strym import strymread
import strym
import copy

outputfolder = '../data/output/'

# %%
# removes the times during which the ACC is on and engaged, and returns a new strym object
def removeACC(strym_obj):
    frames = []
    
    timeslices = strym_obj.time_subset(conditions="cruise control on")
    df = strym_obj.dataframe
    # we have times when ACC is on, now we need to remove those times, so if 
    # our drive is from t0 to tN
    # acc is on from t1 to t2, t8 to t30, t50 to t65 ,then we'll have 
    # ( (t1, t2), (t8, t30), (t50, t65))
    # so we'll look to KEEP times
    # (0, t1), (t2, t8), (t30, t50), (t65, -1) 
#     print('Timeslices of acc on are:', timeslices)
#   JMS you have to check the first array value
#     if len(timeslices) < 1:
    if len(timeslices[0]) < 1:
#         print('Appending frames no matter what')
        frames.append(df)
    else:
        # always set the first one before the loop
#         print('doing the first one')
        import datetime as dt
        frame = df.loc[ pd.Timestamp(df.Time[0]) : timeslices[0][0][0]]
        frames.append(frame)
        for ii in range(len(timeslices[0])):
#             if ii == 0:
#             elif ii == len(timeslices[0])-1:
#                 frame = df.loc[ timeslices[0][ii][1] : ]
#             else:
            if ii > 0:
#                 print('doing a middle one from time ', timeslices[0][ii-1][1], ' to ', timeslices[0][ii][0])
                frame = df.loc[ timeslices[0][ii-1][1] : timeslices[0][ii][0]]
                frames.append(frame)
        # always do the last one
#         print('doing the last one')
        frame = df.loc [ timeslices[0][len(timeslices)-1][1]:pd.Timestamp(df.Time[-1]) ]
        frames.append(frame)
#     print(frames)
    # return the new dataframe(s), using style from strym
    result = copy.deepcopy(strym_obj)
    result_frames = pd.concat(frames)
    result.dataframe = result_frames
    return result, timeslices[0]

def getOutputFilenamePrefix(csvfile):
    # get the end of the file only
    import os
    return os.path.basename(csvfile).split('.')[0]

# get time headway in m/s (assumes input speeds are in m/s)
def time2timeheadway(lead_dist_all,speed_subset):
    result = pd.DataFrame()
    speed_s, lead_dist_s = strymread.ts_sync(speed_subset,lead_dist_all, method='previous')
    result = speed_s[['Time','Message']].copy()
    # go ahead and convert to m/s
    result['Message'] = lead_dist_s['Message'] / (speed_s['Message'])
    return result, lead_dist_s

# adding in the plotDetails function to the top
def plotDetails(speeds,lead_dists,time_headways):
    fig, ax = strymread.create_fig(3)
    for jj in range(len(lead_dists)):
        ax[0].scatter(x=speeds[jj]['Time'] - speeds[jj]['Time'][0],y=speeds[jj]['Message'])
        ax[0].set(xlabel='Time (s) from start of drive',ylabel='Speed (m/s)',title='Speed vs. Time')
        ax[1].scatter(x=lead_dists[jj]['Time'] - lead_dists[jj]['Time'][0],y=lead_dists[jj]['Message'])
        ax[1].set(xlabel='Time (s) from start of drive',ylabel='Lead vehicle longitudinal distance (m)',title='Lead Distance vs. Time')
        ax[2].scatter(x=time_headways[jj]['Time'] - time_headways[jj]['Time'][0],y=time_headways[jj]['Message'])
        ax[2].set(xlabel='Time (s) from start of drive',ylabel='Time Headway (s)',title='Time Headway')

# %%
# change this to your data folder

# datafolder='/Users/sprinkle/work/data/sally/2021_08_09/'
datafolder = '../data/input/libpanda/'
# datafolder='/Users/sallykim/Desktop/2021_08_09/'


import glob
csvlist = glob.glob(datafolder+"**/*2T3*CAN*.csv", recursive=True)

num_of_files = len(csvlist)
print("Total number of datafiles in {} is {}.".format(datafolder, num_of_files))
# dbcfile = '../examples/newToyotacode.dbc'
# Out:
# Total number of datafiles in ../data/input/libpanda/ is 430.

# %%
# choose the first file, and then plot the speed, as well as the lead vehicle distance
# Look in Minitest 1 or in 

#dbcfile_17 = '/Users/sallykim/opt/miniconda3/lib/python3.9/site-packages/strym/dbc/toyota_rav4_hybrid.dbc'
datafile_17 = datafolder+'2021-08-09-17-42-45_2T3Y1RFV8KC014025_CAN_Messages.csv'
#data_17 = pd.read_csv(datafile_17)

# %%
r00 = strymread(datafile_17)
r0, removed =removeACC(r00)

speed = r0.speed()
try:
    speed_17 = r0.get_ts('SPEED','SPEED')
    speed_17.Message = speed_17.Message*(1000/3600)
    long_dist_17 = r0.get_ts('LEAD_INFO','LEAD_LONG_DIST')
    long_dist_17_2 = r0.lead_distance()
except:
    print('Oops, a specific error message Sally writes')
# Out:
# [2022_07_21_17_50_20] (root) INFO: Vehicle model infered is toyota-rav4-2019
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-178-dd84c2731adf> in <module>
# ----> 1 r00 = strymread(datafile_17)
#       2 r0, removed =removeACC(r00)
#       3
#       4 speed = r0.speed()
#       5 try:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/strym/strymread.py in __init__(self, csvfile, dbcfile, **kwargs)
#     394         self.success = True
#     395
# --> 396         self.dataframe =  self.timeindex(self.dataframe, inplace=True)
#     397         self.dataframe_raw = None
#     398         if self.bus is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/strym/strymread.py in timeindex(df, inplace)
#    3243         Time = pd.to_datetime(newdf['Time'], unit='s')
#    3244         newdf.reset_index(drop=True, inplace=True)
# -> 3245         newdf['Clock'] = pd.DatetimeIndex(Time).tolist()
#    3246
#    3247         if inplace:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/datetimelike.py in tolist(self)
#     230         Return a list of the underlying data.
#     231         """
# --> 232         return list(self.astype(object))
#     233
#     234     def min(self, axis=None, skipna=True, *args, **kwargs):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/extension.py in astype(self, dtype, copy)
#     314             return self
#     315
# --> 316         new_values = self._data.astype(dtype, copy=copy)
#     317
#     318         # pass copy=False because any copying will be done in the
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in astype(self, dtype, copy)
#     608         elif is_period_dtype(dtype):
#     609             return self.to_period(freq=dtype.freq)
# --> 610         return dtl.DatetimeLikeArrayMixin.astype(self, dtype, copy)
#     611
#     612     # -----------------------------------------------------------------
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/datetimelike.py in astype(self, dtype, copy)
#     343
#     344         if is_object_dtype(dtype):
# --> 345             return self._box_values(self.asi8.ravel()).reshape(self.shape)
#     346         elif is_string_dtype(dtype) and not is_categorical_dtype(dtype):
#     347             if is_extension_array_dtype(dtype):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/datetimelike.py in _box_values(self, values)
#     225         apply box func to passed values
#     226         """
# --> 227         return lib.map_infer(values, self._box_func)
#     228
#     229     def __iter__(self):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in _box_func(self, x)
#     483
#     484     def _box_func(self, x) -> Union[Timestamp, NaTType]:
# --> 485         return Timestamp(x, freq=self.freq, tz=self.tz)
#     486
#     487     @property
#
# KeyboardInterrupt:

# %%
# choose the first file, and then plot the speed, as well as the lead vehicle distance
# Look in Minitest 1 or in 
fig, ax = strymread.create_fig(2)
ax[0].scatter(x=speed_17['Time'] - speed_17['Time'][0],y=speed_17['Message'])
ax[0].set(xlabel='Time (s) from start of drive',ylabel='Speed (m/s)',title='Speed vs. Time')
ax[1].scatter(x=long_dist_17_2['Time'] - long_dist_17_2['Time'][0],y=long_dist_17_2['Message'])
ax[1].set(xlabel='Time (s) from start of drive',ylabel='Lead vehicle longitudinal distance (m)',title='Lead Distance vs. Time')
# Out:
# [Text(0.5, 17.00000000000003, 'Time (s) from start of drive'),
#  Text(31.75, 0.5, 'Lead vehicle longitudinal distance (m)'),
#  Text(0.5, 1.0, 'Lead Distance vs. Time')]

# %%
# find all times where the lead vehicle distance changes by more than 5

# 1. we're going to remove all times where we have >250 m and create chunks of data
lead_dist = long_dist_17_2
lead_dist_f = lead_dist[lead_dist["Message"]<200]

# %%
fig, ax = strymread.create_fig(2)
ax[0].scatter(x=speed_17['Time'] - speed_17['Time'][0],y=speed_17['Message'])
ax[0].set(xlabel='Time (s) from start of drive',ylabel='Speed (m/s)',title='Speed vs. Time')
ax[1].scatter(x=lead_dist_f['Time'] - lead_dist_f['Time'][0],y=lead_dist_f['Message'])
ax[1].set(xlabel='Time (s) from start of drive',ylabel='Lead vehicle longitudinal distance (m)',title='Lead Distance vs. Time')
# Out:
# [Text(0.5, 94.72222222222219, 'Time (s) from start of drive'),
#  Text(135.47222222222223, 0.5, 'Lead vehicle longitudinal distance (m)'),
#  Text(0.5, 1.0, 'Lead Distance vs. Time')]

# %%
lead_dist_chunks = strymread.create_chunks(
        lead_dist_f,
        # look for any 'big' differences from time to time
        continuous_threshold=5,
        column_of_interest='Message',
#        plot=True,
    )

# now, remove any values where the duration of this chunk is less than 5 seconds
min_duration = 5
lead_dist_chunks_copy = lead_dist_chunks
for jj in reversed(range(len(lead_dist_chunks_copy))):
    chunk = lead_dist_chunks[jj]
    duration = chunk.Time[-1] - chunk.Time[0]
    if duration < min_duration:
        print('Removing element of duration ', duration)
        lead_dist_chunks.pop(jj)
    else:
        print('Keeping element of duration ', duration)

print('We now have ', len(lead_dist_chunks), ' drives that are longer than ', min_duration, ' seconds')
# Out:
# Removing element of duration  0.0
# Keeping element of duration  23.60106110572815
# Removing element of duration  4.000278949737549
# Keeping element of duration  20.20098900794983
# Removing element of duration  4.60017204284668
# Keeping element of duration  29.40112614631653
# Keeping element of duration  30.374499082565308
# Keeping element of duration  21.000452995300293
# Keeping element of duration  6.000230073928833
# Removing element of duration  3.0703799724578857
# Keeping element of duration  66.4016969203949
# Removing element of duration  4.40029501914978
# Keeping element of duration  6.20074987411499
# Removing element of duration  0.5349910259246826
# Removing element of duration  0.4003150463104248
# Removing element of duration  2.399919033050537
# Removing element of duration  1.7998030185699463
# Keeping element of duration  39.801121950149536
# Keeping element of duration  107.4036660194397
# Keeping element of duration  191.60480308532715
# Removing element of duration  0.0
# Removing element of duration  0.19900107383728027
# Removing element of duration  0.0
# Removing element of duration  0.0
# Removing element of duration  1.2000179290771484
# Keeping element of duration  685.6225509643555
# Removing element of duration  2.002223014831543
# Keeping element of duration  60.200562953948975
# Keeping element of duration  52.947731018066406
# Keeping element of duration  43.30400586128235
# Removing element of duration  0.0
# Removing element of duration  0.0
# Removing element of duration  0.0002009868621826172
# Keeping element of duration  32.775553941726685
# Keeping element of duration  6.629398822784424
# Removing element of duration  0.20055603981018066
# Removing element of duration  0.0
# Keeping element of duration  24.205429077148438
# Removing element of duration  0.0
# Removing element of duration  3.0006909370422363
# Removing element of duration  3.000593900680542
# Removing element of duration  0.0
# Removing element of duration  0.39926719665527344
# Removing element of duration  1.5709660053253174
# Keeping element of duration  6.98567008972168
# Removing element of duration  0.0
# Removing element of duration  0.799868106842041
# Keeping element of duration  22.95807194709778
# Keeping element of duration  17.400701999664307
# Removing element of duration  0.5997979640960693
# Removing element of duration  4.600661039352417
# Removing element of duration  2.5998830795288086
# Keeping element of duration  102.46262693405151
# Removing element of duration  0.00015997886657714844
# Removing element of duration  0.0
# Removing element of duration  0.028895139694213867
# We now have  22  drives that are longer than  5  seconds

# %%
# next step: let's divide these up (if you can) OR you can instead try to calculate the time headway across these.
# to do that:
# 1) create a resampled version of two different timeseries
# e.g.,
# val1_sampled, val2_sampled = strymread.ts_sync(ts_val1, ts_val2)



speed = speed_17
lead_dist = lead_dist_chunks

result_speed = []
result_lead_dist = []
result_time_headway = []
time_headway = pd.DataFrame()

for lead_dist in lead_dist_chunks:
    speed_s, lead_dist_s = strymread.ts_sync(speed,lead_dist, method='nearest')
    result_speed.append(speed_s)
    #look for an exmaple where someone creates a new signal based on math with individual messages
    result_lead_dist.append(lead_dist_s)
    time_headway = speed_s[['Time','Message']].copy()
    time_headway['Message'] = lead_dist_s['Message'] / speed_s['Message']
    result_time_headway.append(time_headway)
# 2) divide the distance by the velocity to come up with the time headway
print( 'len(result_speed)=', len(result_speed), ', len(result_lead_dist)=', len(result_lead_dist), ', time headway = ', (len(result_time_headway)))
# Out:
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2767: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2820: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2767: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2820: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2767: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2820: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2767: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2820: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2767: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2820: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2767: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2820: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2767: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2820: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2767: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2820: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2767: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2820: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2767: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2820: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2767: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2820: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2767: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2820: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2767: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2820: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2767: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2820: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2767: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2820: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2767: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2820: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2767: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2820: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2767: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2820: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2767: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2820: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2767: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2820: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2767: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2820: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2767: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/sallykim/opt/miniconda3/lib/python3.8/site-packages/strym/strymread.py:2820: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# len(result_speed)= 22 , len(result_lead_dist)= 22 , time headway =  22

# %%
fig, ax = strymread.create_fig(3)

for jj in range(len(result_lead_dist)):
   ax[0].scatter(x=result_speed[jj]['Time'] - result_speed[jj]['Time'][0],y=result_speed[jj]['Message'])
   ax[0].set(xlabel='Time (s) from start of drive',ylabel='Speed (m/s)',title='Speed vs. Time')
   ax[1].scatter(x=result_lead_dist[jj]['Time'] - result_lead_dist[jj]['Time'][0],y=result_lead_dist[jj]['Message'])
   ax[1].set(xlabel='Time (s) from start of drive',ylabel='Lead vehicle longitudinal distance (m)',title='Lead Distance vs. Time')
   ax[2].scatter(x=result_time_headway[jj]['Time'] - result_time_headway[jj]['Time'][0],y=result_time_headway[jj]['Message'])
   ax[2].set(xlabel='Time (s) from start of drive',ylabel='Time Heaway (s)',title='Speed vs. Time')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 3>()
#       1 fig, ax = strymread.create_fig(3)
# ----> 3 for jj in range(len(result_lead_dist)):
#       4    ax[0].scatter(x=result_speed[jj]['Time'] - result_speed[jj]['Time'][0],y=result_speed[jj]['Message'])
#       5    ax[0].set(xlabel='Time (s) from start of drive',ylabel='Speed (m/s)',title='Speed vs. Time')
#
# NameError: name 'result_lead_dist' is not defined

# %%
fig, ax = strymread.create_fig(1)

for jj in range(len(result_lead_dist)):
    ax[0].scatter(x=result_time_headway[jj]['Time'] - result_time_headway[jj]['Time'][0],y=result_time_headway[jj]['Message'])
    ax[0].set(xlabel='Time (s) from start of drive',ylabel='Time Heaway (s)',title='Speed vs. Time')
plt.ylim([0,5])
# Out:
# (0.0, 5.0)

# %%
# remove all times where the lead vehicle distance is > 200

# %%
# print(result_speed)

# %%
def time2timeheadway(lead_dist_all,speed_subset):
    result = pd.DataFrame()
    speed_s, lead_dist_s = strymread.ts_sync(speed_subset,lead_dist_all, method='previous')
    result = speed_s[['Time','Message']].copy()
    # go ahead and convert to m/s
    result['Message'] = lead_dist_s['Message'] / speed_s['Message']
    return result, lead_dist_s

# %%
def plotDetails(speeds,lead_dists,time_headways):
    fig, ax = strymread.create_fig(3)
    for jj in range(len(lead_dists)):
        ax[0].scatter(x=speeds[jj]['Time'] - speeds[jj]['Time'][0],y=speeds[jj]['Message'])
        ax[0].set(xlabel='Time (s) from start of drive',ylabel='Speed (m/s)',title='Speed vs. Time')
        ax[1].scatter(x=lead_dists[jj]['Time'] - lead_dists[jj]['Time'][0],y=lead_dists[jj]['Message'])
        ax[1].set(xlabel='Time (s) from start of drive',ylabel='Lead vehicle longitudinal distance (m)',title='Lead Distance vs. Time')
        ax[2].scatter(x=time_headways[jj]['Time'] - time_headways[jj]['Time'][0],y=time_headways[jj]['Message'])
        ax[2].set(xlabel='Time (s) from start of drive',ylabel='Time Headway (s)',title='Time Headway')

# %%
def returnTimeHeadwaysByRegion(input_speed_chunk, lead_dist_f, min_speed, max_speed):
    speeds = []
    distances = []
    headways = []
    region = input_speed_chunk[(input_speed_chunk['Message'] > min_speed) & (input_speed_chunk['Message'] < max_speed)]
    if len(region) > 0:
        try:
            # we need to make chunks out of this to make the plots readable
            speed_chunks = strymread.create_chunks(
                region,
                # look for any 'big' differences from time to time
                continuous_threshold=2,
                column_of_interest='Time',
        #        plot=True,
            )
            for speed_chunk in speed_chunks:
                speeds.append(speed_chunk)
                th, ld = time2timeheadway(lead_dist_f, speed_chunk)
                headways.append(th)
                distances.append(ld)
                #plotDetails(r0_v,ld0,th0)
        except:
            print('Something went wrong, continuing if we can')



    return speeds, distances, headways

# %%
r0_v = []
r1_v = []
r2_v = []
r3_v = []
r4_v = []
r5_v = []

th0 = []
th1 = []
th2 = []
th3 = []
th4 = []
th5 = []

ld0 = []
ld1 = []
ld2 = []
ld3 = []
ld4 = []
ld5 = []

completed_files = []

# %%
for file in csvlist[0:100]:
    #read in the strym 
    if file in completed_files:
        print('Already processed filed ', file, ', skipping...')
        continue
    print('reading file ', file)
    outputfile = getOutputFilenamePrefix(file) + '.pickle'
    r00 = strymread(file)
    r0, removed = removeACC(r00)
    speed_17 = r0.speed()
    
    lead_dist = r0.lead_distance()
    lead_dist_f = lead_dist[lead_dist["Message"]<200]
    
    lead_dist_chunks = strymread.create_chunks(
            lead_dist_f,
            # look for any 'big' differences from time to time
            continuous_threshold=5,
            column_of_interest='Message',
    #        plot=True,
        )

    # now, remove any values where the duration of this chunk is less than 5 seconds
    min_duration = 5
    lead_dist_chunks_copy = lead_dist_chunks
    for jj in reversed(range(len(lead_dist_chunks_copy))):
        chunk = lead_dist_chunks[jj]
        duration = chunk.Time[-1] - chunk.Time[0]
        if duration < min_duration:
            print('Removing element of duration ', duration)
            lead_dist_chunks.pop(jj)
        else:
            print('Keeping element of duration ', duration)

    print('We now have ', len(lead_dist_chunks), ' drives that are longer than ', min_duration, ' seconds')

    speed = speed_17
#     lead_dist = lead_dist_chunks

    result_speed = []
    result_lead_dist = []
    result_time_headway = []
    time_headway = pd.DataFrame()

    for lead_dist in lead_dist_chunks:
        speed_s, lead_dist_s = strymread.ts_sync(speed,lead_dist, method='previous')
        result_speed.append(speed_s)
        
        #look for an exmaple where someone creates a new signal based on math with individual messages
        result_lead_dist.append(lead_dist_s)
        time_headway = speed_s[['Time','Message']].copy()
        time_headway['Message'] = lead_dist_s['Message'] / speed_s['Message']
        result_time_headway.append(time_headway)
    # 2) divide the distance by the velocity to come up with the time headway
    print( 'len(result_speed)=', len(result_speed), ', len(result_lead_dist)=', len(result_lead_dist), ', time headway = ', (len(result_time_headway)))
    
    for chunk in result_speed:
        # SALLY OK time to add in more regions here if you can. 
        
        # hack nevermind this is not working
#         speed0, th, ld = returnTimeHeadwaysByRegion(chunk, lead_dist_f, 0, 5)
#         for ii in range(len(speed0)):             
#             r0_v.append(speed0[ii])
#             th0.append(th[ii])
#             ld0.append(ld[ii])
        
        region0 = chunk[(chunk['Message'] > 0) & (chunk['Message'] < 5)]
        if len(region0) > 0:
            try:
                # we need to make chunks out of this to make the plots readable
                speed_chunks = strymread.create_chunks(
                    region0,
                    # look for any 'big' differences from time to time
                    continuous_threshold=2,
                    column_of_interest='Time',
            #        plot=True,
                )
                for speed_chunk in speed_chunks:
                    r0_v.append(speed_chunk)
                    th, ld = time2timeheadway(lead_dist_f, speed_chunk)
                    th0.append(th)
                    ld0.append(ld)
                    #plotDetails(r0_v,ld0,th0)
            except:
                print('Something went wrong, continuing if we can')
        
     
        
        region1 =  chunk[(chunk['Message'] > 5) & (chunk['Message'] < 10)]
        if len(region1) > 0:
            try:
                # we need to make chunks out of this to make the plots readable
                speed_chunks = strymread.create_chunks(
                    region1,
                    # look for any 'big' differences from time to time
                    continuous_threshold=2,
                    column_of_interest='Time',
            #        plot=True,
                )
                for speed_chunk in speed_chunks:

                    r1_v.append(speed_chunk)
                    th, ld = time2timeheadway(lead_dist_f, speed_chunk)
                    th1.append(th)
                    ld1.append(ld)
                    #plotDetails(r1_v,ld1,th1)
            except:
                print('Something went wrong, continuing if we can')
        
        
        region2 =  chunk[(chunk['Message'] > 10) & (chunk['Message'] < 15)]
        if len(region2) > 0:
            try:
                # we need to make chunks out of this to make the plots readable
                speed_chunks = strymread.create_chunks(
                    region2,
                    # look for any 'big' differences from time to time
                    continuous_threshold=2,
                    column_of_interest='Time',
            #        plot=True,
                )
                for speed_chunk in speed_chunks:


                    r2_v.append(region2)
                    th, ld = time2timeheadway(lead_dist_f, speed_chunk)
                    th2.append(th)
                    ld2.append(ld)
                    #plotDetails(r2_v,ld2,th2)
            except:
                print('Something went wrong, continuing if we can')
        
        
        region3 =  chunk[(chunk['Message'] > 15) & (chunk['Message'] < 20)]
        if len(region3) > 0:
            try:
                # we need to make chunks out of this to make the plots readable
                speed_chunks = strymread.create_chunks(
                    region3,
                    # look for any 'big' differences from time to time
                    continuous_threshold=2,
                    column_of_interest='Time',
            #        plot=True,
                )
                for speed_chunk in speed_chunks:


                    r3_v.append(region3)
                    th, ld = time2timeheadway(lead_dist_f, speed_chunk)
                    th3.append(th)
                    ld3.append(ld)
                    #plotDetails(r3_v,ld3,th3)
            except:
                print('Something went wrong, continuing if we can')

        
        region4 =  chunk[(chunk['Message'] > 20) & (chunk['Message'] < 25)]
        if len(region4) > 0:
            try:
                # we need to make chunks out of this to make the plots readable
                speed_chunks = strymread.create_chunks(
                    region4,
                    # look for any 'big' differences from time to time
                    continuous_threshold=2,
                    column_of_interest='Time',
            #        plot=True,
                )
                for speed_chunk in speed_chunks:


                    r4_v.append(region4)
                    th, ld = time2timeheadway(lead_dist_f, speed_chunk)
                    th4.append(th)
                    ld4.append(ld)
                    #plotDetails(r4_v,ld4,th4)
            except:
                print('Something went wrong, continuing if we can')

        
        region5 =  chunk[(chunk['Message'] > 25) & (chunk['Message'] < 30)]
        if len(region5) > 0:
            try:
                # we need to make chunks out of this to make the plots readable
                speed_chunks = strymread.create_chunks(
                    region5,
                    # look for any 'big' differences from time to time
                    continuous_threshold=2,
                    column_of_interest='Time',
            #        plot=True,
                )
                for speed_chunk in speed_chunks:


                    r5_v.append(region5)
                    th, ld = time2timeheadway(lead_dist_f, speed_chunk)
                    th5.append(th)
                    ld5.append(ld)
                    #plotDetails(r5_v,ld5,th5)
            except:
                print('Something went wrong, continuing if we can')
                
                
    completed_files.append(file)
# Out:
# reading file  ../data/input/libpanda/2021_01_04/2021-01-04-22-36-11_2T3Y1RFV8KC014025_CAN_Messages.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-e32b5f7ecc58> in <module>
#       6     print('reading file ', file)
#       7     outputfile = getOutputFilenamePrefix(file) + '.pickle'
# ----> 8     r00 = strymread(file)
#       9     r0, removed = removeACC(r00)
#      10     speed_17 = r0.speed()
#
# /opt/conda/lib/python3.8/site-packages/strym/strymread.py in __init__(self, csvfile, dbcfile, **kwargs)
#     275                 if not is_windows:
#     276                     word_counts = Popen(['wc', '-l', self.csvfile], stdin=PIPE, stdout=PIPE, stderr=PIPE)
# --> 277                     output, err = word_counts.communicate()
#     278                     output = output.decode("utf-8")
#     279                     output = output.strip()
#
# /opt/conda/lib/python3.8/subprocess.py in communicate(self, input, timeout)
#    1022
#    1023             try:
# -> 1024                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1025             except KeyboardInterrupt:
#    1026                 # https://bugs.python.org/issue25942
#
# /opt/conda/lib/python3.8/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1864                             'failed to raise TimeoutExpired.')
#    1865
# -> 1866                     ready = selector.select(timeout)
#    1867                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    1868
#
# /opt/conda/lib/python3.8/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %%
filename2 = '../data/input/libpanda/2021_01_04/2021-01-04-22-36-11_2T3Y1RFV8KC014025_CAN_Messages.csv'
output2 = getOutputFilenamePrefix(filename2)
print(output2)
# Out:
# 2021-01-04-22-36-11_2T3Y1RFV8KC014025_CAN_Messages

# %%
print('Completed processing ', len(completed_files), ' files, with ', len(r0_v)+len(r1_v)+len(r2_v)+len(r3_v)+len(r4_v), ' drive segments')
# Out:
# Completed processing  18  files, with  337  drive segments

# %%
# SALLY OK here we are, ready to print the results and add in more regions above. 
plotDetails(r0_v,ld0,th0) 
plotDetails(r1_v,ld1,th1) 
plotDetails(r2_v,ld2,th2) 
plotDetails(r3_v,ld3,th3) 
plotDetails(r4_v,ld4,th4) 
plotDetails(r5_v,ld5,th5)

# %% [markdown]
# Trying to create a parallel version.

# %%
r0_v = []
r1_v = []
r2_v = []
r3_v = []
r4_v = []
r5_v = []

th0 = []
th1 = []
th2 = []
th3 = []
th4 = []
th5 = []

ld0 = []
ld1 = []
ld2 = []
ld3 = []
ld4 = []
ld5 = []
from os.path import exists

import pickle

def parallelComputer(file):
    #read in the strym 
    if file in completed_files:
        print('Already processed filed ', file, ', skipping...')
        return None
    print('reading file ', file)
    outputfile = getOutputFilenamePrefix(file)
    if exists(outputfile):
        print('File ', outputfile, 'already exists, exiting.')
        
    r00 = strymread(file)
    r0, removed = removeACC(r00)
    speed_17 = r0.speed()
    
    lead_dist = r0.lead_distance()
    lead_dist_f = lead_dist[lead_dist["Message"]<200]
    
    lead_dist_chunks = strymread.create_chunks(
            lead_dist_f,
            # look for any 'big' differences from time to time
            continuous_threshold=5,
            column_of_interest='Message',
    #        plot=True,
        )

    # now, remove any values where the duration of this chunk is less than 5 seconds
    min_duration = 5
    lead_dist_chunks_copy = lead_dist_chunks
    for jj in reversed(range(len(lead_dist_chunks_copy))):
        chunk = lead_dist_chunks[jj]
        duration = chunk.Time[-1] - chunk.Time[0]
        if duration < min_duration:
            print('Removing element of duration ', duration)
            lead_dist_chunks.pop(jj)
        else:
            print('Keeping element of duration ', duration)

    print('We now have ', len(lead_dist_chunks), ' drives that are longer than ', min_duration, ' seconds')

    speed = speed_17
#     lead_dist = lead_dist_chunks

    result_speed = []
    result_lead_dist = []
    result_time_headway = []
    time_headway = pd.DataFrame()

    for lead_dist in lead_dist_chunks:
        speed_s, lead_dist_s = strymread.ts_sync(speed,lead_dist, method='previous')
        result_speed.append(speed_s)
        
        #look for an exmaple where someone creates a new signal based on math with individual messages
        result_lead_dist.append(lead_dist_s)
        time_headway = speed_s[['Time','Message']].copy()
        time_headway['Message'] = lead_dist_s['Message'] / speed_s['Message']
        result_time_headway.append(time_headway)
    # 2) divide the distance by the velocity to come up with the time headway
    print( 'len(result_speed)=', len(result_speed), ', len(result_lead_dist)=', len(result_lead_dist), ', time headway = ', (len(result_time_headway)))
    
    for chunk in result_speed:
        # SALLY OK time to add in more regions here if you can. 
        
        # hack nevermind this is not working
#         speed0, th, ld = returnTimeHeadwaysByRegion(chunk, lead_dist_f, 0, 5)
#         for ii in range(len(speed0)):             
#             r0_v.append(speed0[ii])
#             th0.append(th[ii])
#             ld0.append(ld[ii])
        
        region0 = chunk[(chunk['Message'] > 0) & (chunk['Message'] < 5)]
        if len(region0) > 0:
            try:
                # we need to make chunks out of this to make the plots readable
                speed_chunks = strymread.create_chunks(
                    region0,
                    # look for any 'big' differences from time to time
                    continuous_threshold=2,
                    column_of_interest='Time',
            #        plot=True,
                )
                for speed_chunk in speed_chunks:
                    r0_v.append(speed_chunk)
                    th, ld = time2timeheadway(lead_dist_f, speed_chunk)
                    th0.append(th)
                    ld0.append(ld)
                    #plotDetails(r0_v,ld0,th0)
            except:
                print('Something went wrong, continuing if we can')
        
     
        
        region1 =  chunk[(chunk['Message'] > 5) & (chunk['Message'] < 10)]
        if len(region1) > 0:
            try:
                # we need to make chunks out of this to make the plots readable
                speed_chunks = strymread.create_chunks(
                    region1,
                    # look for any 'big' differences from time to time
                    continuous_threshold=2,
                    column_of_interest='Time',
            #        plot=True,
                )
                for speed_chunk in speed_chunks:

                    r1_v.append(speed_chunk)
                    th, ld = time2timeheadway(lead_dist_f, speed_chunk)
                    th1.append(th)
                    ld1.append(ld)
                    #plotDetails(r1_v,ld1,th1)
            except:
                print('Something went wrong, continuing if we can')
        
        
        region2 =  chunk[(chunk['Message'] > 10) & (chunk['Message'] < 15)]
        if len(region2) > 0:
            try:
                # we need to make chunks out of this to make the plots readable
                speed_chunks = strymread.create_chunks(
                    region2,
                    # look for any 'big' differences from time to time
                    continuous_threshold=2,
                    column_of_interest='Time',
            #        plot=True,
                )
                for speed_chunk in speed_chunks:


                    r2_v.append(region2)
                    th, ld = time2timeheadway(lead_dist_f, speed_chunk)
                    th2.append(th)
                    ld2.append(ld)
                    #plotDetails(r2_v,ld2,th2)
            except:
                print('Something went wrong, continuing if we can')
        
        
        region3 =  chunk[(chunk['Message'] > 15) & (chunk['Message'] < 20)]
        if len(region3) > 0:
            try:
                # we need to make chunks out of this to make the plots readable
                speed_chunks = strymread.create_chunks(
                    region3,
                    # look for any 'big' differences from time to time
                    continuous_threshold=2,
                    column_of_interest='Time',
            #        plot=True,
                )
                for speed_chunk in speed_chunks:


                    r3_v.append(region3)
                    th, ld = time2timeheadway(lead_dist_f, speed_chunk)
                    th3.append(th)
                    ld3.append(ld)
                    #plotDetails(r3_v,ld3,th3)
            except:
                print('Something went wrong, continuing if we can')

        
        region4 =  chunk[(chunk['Message'] > 20) & (chunk['Message'] < 25)]
        if len(region4) > 0:
            try:
                # we need to make chunks out of this to make the plots readable
                speed_chunks = strymread.create_chunks(
                    region4,
                    # look for any 'big' differences from time to time
                    continuous_threshold=2,
                    column_of_interest='Time',
            #        plot=True,
                )
                for speed_chunk in speed_chunks:


                    r4_v.append(region4)
                    th, ld = time2timeheadway(lead_dist_f, speed_chunk)
                    th4.append(th)
                    ld4.append(ld)
                    #plotDetails(r4_v,ld4,th4)
            except:
                print('Something went wrong, continuing if we can')

        
        region5 =  chunk[(chunk['Message'] > 25) & (chunk['Message'] < 30)]
        if len(region5) > 0:
            try:
                # we need to make chunks out of this to make the plots readable
                speed_chunks = strymread.create_chunks(
                    region5,
                    # look for any 'big' differences from time to time
                    continuous_threshold=2,
                    column_of_interest='Time',
            #        plot=True,
                )
                for speed_chunk in speed_chunks:


                    r5_v.append(region5)
                    th, ld = time2timeheadway(lead_dist_f, speed_chunk)
                    th5.append(th)
                    ld5.append(ld)
                    #plotDetails(r5_v,ld5,th5)
            except:
                print('Something went wrong, continuing if we can')
    
    result = [ r0_v, r1_v, r2_v, r3_v, r4_v, r5_v, 
             th0, th1, th2, th3, th4, th5,
             ld0, ld1, ld2, ld3, ld4, ld5 ]
    
    with open(outputfolder + outputfile, 'wb') as f:
        pickle.dump(result , f)    

    return file

# %%
import multiprocessing
from joblib import Parallel, delayed
# not using this
# num_cores = min(multiprocessing.cpu_count(),4)
# now we go to town for ALL of them

# completed_files is defined above

try:
    file = Parallel(n_jobs=-2,verbose=99)(delayed(parallelComputer)(file)
                                                        for file in csvlist[0:100])
except Exception as e:
    print('We had a problem in the parallel stack, see, ', e)

# now append everything back
# Out:
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   1 tasks      | elapsed:   59.5s
# [Parallel(n_jobs=-2)]: Done   2 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-2)]: Done   3 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-2)]: Done   5 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-2)]: Done   6 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-2)]: Done   7 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-2)]: Done   8 tasks      | elapsed:  2.0min

# %%
print('Completed processing ', len(completed_files), ' files, with ', len(r0_v)+len(r1_v)+len(r2_v)+len(r3_v)+len(r4_v), ' drive segments')
# Out:
# Completed processing  0  files, with  0  drive segments

# %%
print(done)
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '../data/input/libpanda/2021_01_19/2021-01-19-22-46-26_2T3Y1RFV8KC014025_CAN_Messages.csv', '../data/input/libpanda/2021_01_21/2021-01-21-22-23-38_2T3Y1RFV8KC014025_CAN_Messages.csv']

# %%
# SALLY OK here we are, ready to print the results and add in more regions above. 
plotDetails(r0_v,ld0,th0) 
plotDetails(r1_v,ld1,th1) 
plotDetails(r2_v,ld2,th2) 
plotDetails(r3_v,ld3,th3) 
plotDetails(r4_v,ld4,th4) 
plotDetails(r5_v,ld5,th5)

# %%
fix,ax = strymread.create_fig(1)
ax[0].scatter(x=lead_dist_f['Time'], y=lead_dist_f['Message'])
ax[0].scatter(x=region0['Time'],y=region0['Message'])

# %%
r0_v = []

for chunk in result_speed:
    region0 = chunk[(chunk['Message'] > 0) & (chunk['Message'] < 5)]
    # only save it if it has nonzero length
    if len(region0) > 0:
        r0_v.append(region0)

# %% [markdown]
# At this point, you have figured out the times that make sense for velocity, but we have an array of those times, and there is a similar array of the other data (like lead vehicle distance), so we don't know where we are in each array unless we iterate over them all. So---we can either track 3 different iterators /or/ we can make a function that returns the values we want, based on the time values we have.

# %%
# pass in the ENTIRE lead distance info, and then the speed dataframes for times where you want time headway.
# then it returns the time headway
def time2timeheadway(lead_dist_all,speed_subset):
    speed_s, lead_dist_s = strymread.ts_sync(speed_subset,lead_dist_all, method='previous')
    time_headway = speed_s[['Time','Message']].copy()
    time_headway['Message'] = lead_dist_s['Message'] / speed_s['Message']
    return time_headway, lead_dist_s

# %% [markdown]
# It looks like we're able to get those values now. Let's now iterate over ALL of the values by speed iteration.

# %%
th0 = []
ld0 = []

for speed in r0_v:
#     region0 = time_headway[time_headway['Time'] == time['Time']]
#     region0 = time_headway.loc[time['Time']]
#     th0.append(region0)  
#     print(region0)
    th, ld = time2timeheadway(long_dist_17_2, speed)
    th0.append(th)
    ld0.append(ld)

# %%
def plotDetails(speeds,lead_dists,time_headways):
    fig, ax = strymread.create_fig(3)
    for jj in range(len(lead_dists)):
        ax[0].scatter(x=speeds[jj]['Time'] - speeds[jj]['Time'][0],y=speeds[jj]['Message'])
        ax[0].set(xlabel='Time (s) from start of drive',ylabel='Speed (m/s)',title='Speed vs. Time')
        ax[1].scatter(x=lead_dists[jj]['Time'] - lead_dists[jj]['Time'][0],y=lead_dists[jj]['Message'])
        ax[1].set(xlabel='Time (s) from start of drive',ylabel='Lead vehicle longitudinal distance (m)',title='Lead Distance vs. Time')
        ax[2].scatter(x=time_headways[jj]['Time'] - time_headways[jj]['Time'][0],y=time_headways[jj]['Message'])
        ax[2].set(xlabel='Time (s) from start of drive',ylabel='Time Headway (s)',title='Time Headway')

# %%
plotDetails(r0_v,ld0,th0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 plotDetails(r0_v,ld0,th0)
#
# Input In [15], in plotDetails(speeds, lead_dists, time_headways)
#       6 ax[1].scatter(x=lead_dists[jj]['Time'] - lead_dists[jj]['Time'][0],y=lead_dists[jj]['Message'])
#       7 ax[1].set(xlabel='Time (s) from start of drive',ylabel='Lead vehicle longitudinal distance (m)',title='Lead Distance vs. Time')
# ----> 8 ax[2].scatter(x=time_headways[jj]['Time'] - time_headways[jj]['Time'][0],y=time_headways[jj]['Message'])
#       9 ax[2].set(xlabel='Time (s) from start of drive',ylabel='Time Headway (s)',title='Time Headway')
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Time'

# %% [markdown]
# Min: 0 s
# Max: 680 s
# Range: 680 s

# %%
r1_v = []

for chunk in result_speed:
    region1 = chunk[(chunk['Message'] > 5) & (chunk['Message'] < 10)]
    # only save it if it has nonzero length
    if len(region1) > 0:
        r1_v.append(region1)

# %%
th1 = []
ld1 = []

for speed in r1_v:
    th, ld = time2timeheadway(long_dist_17_2, speed)
    th1.append(th)
    ld1.append(ld)

# %%
plotDetails(r1_v,ld1,th1)

# %% [markdown]
# Min: 0.2 s
# Max: 18 s
# Range: 17.8 s

# %%
r2_v = []

for chunk in result_speed:
    region2 = chunk[(chunk['Message'] > 10) & (chunk['Message'] < 15)]
    # only save it if it has nonzero length
    if len(region2) > 0:
        r2_v.append(region2)

# %%
th2 = []
ld2 = []

for speed in r2_v:
    th, ld = time2timeheadway(long_dist_17_2, speed)
    th2.append(th)
    ld2.append(ld)

# %%
plotDetails(r2_v,ld2,th2)

# %% [markdown]
# Min: 0.5 s
# Max: 7.5 s
# Range: 7.0 s

# %%
r3_v = []

for chunk in result_speed:
    region3 = chunk[(chunk['Message'] > 15) & (chunk['Message'] < 20)]
    # only save it if it has nonzero length
    if len(region3) > 0:
        r3_v.append(region3)
        
th3 = []
ld3 = []

for speed in r3_v:
    th, ld = time2timeheadway(long_dist_17_2, speed)
    th3.append(th)
    ld3.append(ld)
    
plotDetails(r3_v,ld3,th3)

# %% [markdown]
# Min: 0.2 s
# Max: 2.5 s
# Range: 2.3 s

# %%
r4_v = []

for chunk in result_speed:
    region4 = chunk[(chunk['Message'] > 20) & (chunk['Message'] < 25)]
    # only save it if it has nonzero length
    if len(region4) > 0:
        r4_v.append(region4)
        
th4 = []
ld4 = []

for speed in r4_v:
    th, ld = time2timeheadway(long_dist_17_2, speed)
    th4.append(th)
    ld4.append(ld)
    
plotDetails(r4_v,ld4,th4)

# %% [markdown]
# Min: 0.25 s
# Max: 4.5 s
# Range: 4.25 s

# %%
r5_v = []

for chunk in result_speed:
    region5 = chunk[(chunk['Message'] > 25) & (chunk['Message'] < 30)]
    # only save it if it has nonzero length
    if len(region5) > 0:
        r5_v.append(region5)
        
th5 = []
ld5 = []

for speed in r5_v:
    th, ld = time2timeheadway(long_dist_17_2, speed)
    th5.append(th)
    ld5.append(ld)
    
plotDetails(r5_v,ld5,th5)

# %% [markdown]
# Min: 0.1 s
# Max: 4.2 s
# Range: 4.1 s

# %%
##file_list=['a.csv','b.csv','c.csv']
##TBD

  
#for i in range(1,len(file_list)):
